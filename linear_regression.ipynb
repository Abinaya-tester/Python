# %% [markdown]
# <a href="https://colab.research.google.com/github/AbinayaRajamanikkam/Python/blob/main/linear_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Linear Regression using scipy library

# %%
import matplotlib.pyplot as plt
from scipy import stats
import numpy as np

# original data

a = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
b = np.array([62,76,82,78,50,110,52,89,60,94,100,90,66])

# %%
plt.scatter(a, b)
plt.show()

# %%
#we are using linear regression model to find needed value of iterncept and slope
ls = stats.linregress(a, b)
ls
# Out:
# LinregressResult(slope=np.float64(4.376747608535688), intercept=np.float64(44.284768211920536), rvalue=np.float64(0.9729243941814462), pvalue=np.float64(2.419506868631877e-08), stderr=np.float64(0.3134876098548804), intercept_stderr=np.float64(2.698123645963877))

# %%
z = ls.intercept + ls.slope * a
z
# Out:
# array([ 66.16850625,  74.92200147,  79.29874908,  74.92200147,
#         53.03826343, 118.68947756,  53.03826343,  83.67549669,
#         61.79175865,  92.42899191,  96.80573951,  83.67549669,
#         70.54525386])

# %%
plt.scatter(a, b)
plt.plot(a, z)
plt.show()
